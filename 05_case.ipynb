# %% [markdown]
# # 📰 The News Framing of Artificial Intelligence
# In this notebook you will reproduce a part of the work done by [Nguyen and Hekman (2024)](https://doi.org/10.1007/s00146-022-01511-1) on how media discourses make sense of automation. Authors collected A.I.-related news content from four different (tech-)news outlets that publish in English: The New York Times, The Guardian, Wired, and Gizmodo. Relevant news content was retrieved via search requests for the keywords “A.I.”, “AI”, and “artificial intelligence”. Only articles in which these terms occurred at least twice in the body text or once in the title or short metadata description were included in the final dataset of 3,098 unique items. The timeframe for the analysis spans from January 2010 to May 2021.
#
# Various methods were used and in this notebook you will use:
# 1. Text Pre-processing
# 2. Bag-of-Words (not directly used in the study)
# 3. N-grams (not used in the study, so let's see if results will vary)
# 4. TF-IDF
# 5. K-means clustering
#
# Use the knowledge and skills obtained from the previous notebooks and analyse the corpus of text.

# %% [markdown]
# ### 0. The Libraries You Use
# Best practice is to load all the libraries at the beginning. This helps keeping your notebook organized.

# %%
# Code goes here

# %% [markdown]
# ### 1. Load and Explore the Dataset

# %%
# Code goes here

# %% [markdown]
# ### 2. Text Pre-processing
# In the text pre-processing step authors added the word A.I. and Artifical Intelligence to the stopword list. Why would they have done this?

# %%
# Code goes here

# %% [markdown]
# ### 3. Bag-of-World

# %%
# Code goes here

# %% [markdown]
# ### 4. N-grams

# %%
# Code goes here

# %% [markdown]
# ### 5. TF-IDF

# %%
# Code goes here

# %% [markdown]
# ### 6. K-means Clustering

# %%
# Code goes here
